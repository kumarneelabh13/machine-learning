# %%
a = [1,2,3,1,2,3,1,2,3,1,2,3]
a[0]
a[4:8]
a[2:]
a[:3]
a[:]
# Out:
# [1, 2, 3, 1, 2, 3, 1, 2, 3, 1, 2, 3]

# %%
import numpy as np

# %%
n = np.array(a)
n[1:3]
# Out:
# array([2, 3])

# %%
import pandas as pd

# %%
iris = pd.read_csv('https://archive.ics.uci.edu/ml/machine-learning-databases/iris/iris.data')
type(iris)
iris.tail(20)
# Out:
#      5.1  3.5  1.4  0.2     Iris-setosa
# 129  7.4  2.8  6.1  1.9  Iris-virginica
# 130  7.9  3.8  6.4  2.0  Iris-virginica
# 131  6.4  2.8  5.6  2.2  Iris-virginica
# 132  6.3  2.8  5.1  1.5  Iris-virginica
# 133  6.1  2.6  5.6  1.4  Iris-virginica
# 134  7.7  3.0  6.1  2.3  Iris-virginica
# 135  6.3  3.4  5.6  2.4  Iris-virginica
# 136  6.4  3.1  5.5  1.8  Iris-virginica
# 137  6.0  3.0  4.8  1.8  Iris-virginica
# 138  6.9  3.1  5.4  2.1  Iris-virginica
# 139  6.7  3.1  5.6  2.4  Iris-virginica
# 140  6.9  3.1  5.1  2.3  Iris-virginica
# 141  5.8  2.7  5.1  1.9  Iris-virginica
# 142  6.8  3.2  5.9  2.3  Iris-virginica
# 143  6.7  3.3  5.7  2.5  Iris-virginica
# 144  6.7  3.0  5.2  2.3  Iris-virginica
# 145  6.3  2.5  5.0  1.9  Iris-virginica
# 146  6.5  3.0  5.2  2.0  Iris-virginica
# 147  6.2  3.4  5.4  2.3  Iris-virginica
# 148  5.9  3.0  5.1  1.8  Iris-virginica

# %%
iris.columns = ['sl', 'sw', 'pl', 'pw', 'flower_class']
iris.head()
# Out:
#     sl   sw   pl   pw flower_class
# 0  4.9  3.0  1.4  0.2  Iris-setosa
# 1  4.7  3.2  1.3  0.2  Iris-setosa
# 2  4.6  3.1  1.5  0.2  Iris-setosa
# 3  5.0  3.6  1.4  0.2  Iris-setosa
# 4  5.4  3.9  1.7  0.4  Iris-setosa

# %%
iris.shape
# Out:
# (149, 5)

# %%
iris.dtypes
# Out:
# sl              float64
# sw              float64
# pl              float64
# pw              float64
# flower_class     object
# dtype: object

# %%
iris.describe()
# Out:
#                sl          sw          pl          pw
# count  149.000000  149.000000  149.000000  149.000000
# mean     5.848322    3.051007    3.774497    1.205369
# std      0.828594    0.433499    1.759651    0.761292
# min      4.300000    2.000000    1.000000    0.100000
# 25%      5.100000    2.800000    1.600000    0.300000
# 50%      5.800000    3.000000    4.400000    1.300000
# 75%      6.400000    3.300000    5.100000    1.800000
# max      7.900000    4.400000    6.900000    2.500000

# %%
pd.isnull(iris).sum()
# Out:
# sl              0
# sw              0
# pl              0
# pw              0
# flower_class    0
# dtype: int64

# %%
iris.iloc[0:1, :]
# Out:
#     sl   sw   pl   pw flower_class
# 0  4.9  3.0  1.4  0.2  Iris-setosa

# %%
iris.iloc[1:3,1:2] = np.nan
iris.head()
pd.isnull(iris)
# Out:
#         sl     sw     pl     pw flower_class
# 0    False  False  False  False        False
# 1    False   True  False  False        False
# 2    False   True  False  False        False
# 3    False  False  False  False        False
# 4    False  False  False  False        False
# 5    False  False  False  False        False
# 6    False  False  False  False        False
# 7    False  False  False  False        False
# 8    False  False  False  False        False
# 9    False  False  False  False        False
# 10   False  False  False  False        False
# 11   False  False  False  False        False
# 12   False  False  False  False        False
# 13   False  False  False  False        False
# 14   False  False  False  False        False
# 15   False  False  False  False        False
# 16   False  False  False  False        False
# 17   False  False  False  False        False
# 18   False  False  False  False        False
# 19   False  False  False  False        False
# ...

# %%
iris.sw.fillna(iris.sw.mean(), inplace = True)
iris.head()
# Out:
#     sl       sw   pl   pw flower_class
# 0  4.9  3.00000  1.4  0.2  Iris-setosa
# 1  4.7  3.04966  1.3  0.2  Iris-setosa
# 2  4.6  3.04966  1.5  0.2  Iris-setosa
# 3  5.0  3.60000  1.4  0.2  Iris-setosa
# 4  5.4  3.90000  1.7  0.4  Iris-setosa

# %%
iris.head()
Y
Y
iris.iloc[1:3,:] = np.nan
iris.head()
iris.dropna(inplace = True)
iris.head()
# Out:
#      sl   sw   pl   pw
# 0   4.9  3.0  1.4  0.2
# 11  4.8  3.0  1.4  0.1
# 12  4.3  3.0  1.1  0.1
# 13  5.8  4.0  1.2  0.2
# 14  5.7  4.4  1.5  0.4

# %%
iris.iloc[1:3,1:2] = np.nan
iris.head()
# Out:
#      sl   sw   pl   pw
# 0   4.9  3.0  1.4  0.2
# 11  4.8  NaN  1.4  0.1
# 12  4.3  NaN  1.1  0.1
# 13  5.8  4.0  1.2  0.2
# 14  5.7  4.4  1.5  0.4

# %%
iris.dropna(inplace = True)
iris.head()
# Out:
#      sl   sw   pl   pw
# 0   4.9  3.0  1.4  0.2
# 13  5.8  4.0  1.2  0.2
# 14  5.7  4.4  1.5  0.4
# 15  5.4  3.9  1.3  0.4
# 16  5.1  3.5  1.4  0.3

# %%
iris.reset_index(drop = True, inplace = True)
iris
# Out:
#       sl   sw   pl   pw
# 0    4.9  3.0  1.4  0.2
# 1    5.8  4.0  1.2  0.2
# 2    5.7  4.4  1.5  0.4
# 3    5.4  3.9  1.3  0.4
# 4    5.1  3.5  1.4  0.3
# 5    5.7  3.8  1.7  0.3
# 6    5.1  3.8  1.5  0.3
# 7    5.4  3.4  1.7  0.2
# 8    5.1  3.7  1.5  0.4
# 9    4.6  3.6  1.0  0.2
# 10   5.1  3.3  1.7  0.5
# 11   4.8  3.4  1.9  0.2
# 12   5.0  3.0  1.6  0.2
# 13   5.0  3.4  1.6  0.4
# 14   5.2  3.5  1.5  0.2
# 15   5.2  3.4  1.4  0.2
# 16   4.7  3.2  1.6  0.2
# 17   4.8  3.1  1.6  0.2
# 18   5.4  3.4  1.5  0.4
# 19   5.2  4.1  1.5  0.1
# 20   5.5  4.2  1.4  0.2
# 21   4.9  3.1  1.5  0.1
# 22   5.0  3.2  1.2  0.2
# 23   5.5  3.5  1.3  0.2
# 24   4.9  3.1  1.5  0.1
# 25   4.4  3.0  1.3  0.2
# 26   5.1  3.4  1.5  0.2
# 27   5.0  3.5  1.3  0.3
# 28   4.5  2.3  1.3  0.3
# 29   4.4  3.2  1.3  0.2
# ..   ...  ...  ...  ...
# 107  6.9  3.2  5.7  2.3
# 108  5.6  2.8  4.9  2.0
# 109  7.7  2.8  6.7  2.0
# 110  6.3  2.7  4.9  1.8
# 111  6.7  3.3  5.7  2.1
# 112  7.2  3.2  6.0  1.8
# ...

# %% [markdown]
# #### Matplotlib

# %%
import matplotlib.pyplot as plt
from matplotlib import style

# %%
x = [5,8,10]
y = [10,1,20]
plt.plot(x,y)
plt.title("demo")
plt.xlabel("X")
plt.ylabel("Y")
plt.show()

# %%
plt.plot(x,y, label = 'Value 1', linewidth=5)
x2 = [5,2,12]
y2 = [3,4,8]
plt.plot(x2,y2, label = 'Value 2')
plt.legend()
plt.title("demo")
plt.xlabel("X")
plt.ylabel("Y")
plt.show()

# %%
style.use('ggplot')
plt.bar(x,y, color = 'g')
plt.show()

# %%
a = np.random.randn(10000)
plt.hist(a, 20)
plt.show()

# %% [markdown]
# ### Titanic

# %%
titanic = pd.read_csv('titanic_train.csv')
titanic.head()
del titanic['PassengerId']
del titanic['Name']
del titanic['Ticket']
titanic.head()
# Out:
#    Survived  Pclass     Sex   Age  SibSp  Parch     Fare Cabin Embarked
# 0         0       3    male  22.0      1      0   7.2500   NaN        S
# 1         1       1  female  38.0      1      0  71.2833   C85        C
# 2         1       3  female  26.0      0      0   7.9250   NaN        S
# 3         1       1  female  35.0      1      0  53.1000  C123        S
# 4         0       3    male  35.0      0      0   8.0500   NaN        S

# %%
titanic.shape
# Out:
# (891, 9)

# %%
titanic.isnull().sum()
# Out:
# Survived      0
# Pclass        0
# Sex           0
# Age         177
# SibSp         0
# Parch         0
# Fare          0
# Cabin       687
# Embarked      2
# dtype: int64

# %%
del titanic['Cabin']
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /Users/asingla/anaconda2/envs/py3k/lib/python3.6/site-packages/pandas/indexes/base.py in get_loc(self, key, method, tolerance)
#    2133             try:
# -> 2134                 return self._engine.get_loc(key)
#    2135             except KeyError:
#
# pandas/index.pyx in pandas.index.IndexEngine.get_loc (pandas/index.c:4433)()
#
# pandas/index.pyx in pandas.index.IndexEngine.get_loc (pandas/index.c:4279)()
#
# pandas/src/hashtable_class_helper.pxi in pandas.hashtable.PyObjectHashTable.get_item (pandas/hashtable.c:13742)()
#
# pandas/src/hashtable_class_helper.pxi in pandas.hashtable.PyObjectHashTable.get_item (pandas/hashtable.c:13696)()
#
# KeyError: 'Cabin'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# ...

# %%
titanic.head()
# Out:
#    Survived  Pclass     Sex   Age  SibSp  Parch     Fare Embarked
# 0         0       3    male  22.0      1      0   7.2500        S
# 1         1       1  female  38.0      1      0  71.2833        C
# 2         1       3  female  26.0      0      0   7.9250        S
# 3         1       1  female  35.0      1      0  53.1000        S
# 4         0       3    male  35.0      0      0   8.0500        S

# %%
titanic.describe()
# Out:
#          Survived      Pclass         Age       SibSp       Parch        Fare
# count  891.000000  891.000000  714.000000  891.000000  891.000000  891.000000
# mean     0.383838    2.308642   29.699118    0.523008    0.381594   32.204208
# std      0.486592    0.836071   14.526497    1.102743    0.806057   49.693429
# min      0.000000    1.000000    0.420000    0.000000    0.000000    0.000000
# 25%      0.000000    2.000000   20.125000    0.000000    0.000000    7.910400
# 50%      0.000000    3.000000   28.000000    0.000000    0.000000   14.454200
# 75%      1.000000    3.000000   38.000000    1.000000    0.000000   31.000000
# max      1.000000    3.000000   80.000000    8.000000    6.000000  512.329200

# %%
titanic.Age.fillna(titanic.Age.mean(), inplace = True)
titanic.describe()
# Out:
#          Survived      Pclass         Age       SibSp       Parch        Fare
# count  891.000000  891.000000  891.000000  891.000000  891.000000  891.000000
# mean     0.383838    2.308642   29.699118    0.523008    0.381594   32.204208
# std      0.486592    0.836071   13.002015    1.102743    0.806057   49.693429
# min      0.000000    1.000000    0.420000    0.000000    0.000000    0.000000
# 25%      0.000000    2.000000   22.000000    0.000000    0.000000    7.910400
# 50%      0.000000    3.000000   29.699118    0.000000    0.000000   14.454200
# 75%      1.000000    3.000000   35.000000    1.000000    0.000000   31.000000
# max      1.000000    3.000000   80.000000    8.000000    6.000000  512.329200

# %%
survived = titanic[titanic.Survived == 1]
survived.describe()
didntsurvive = titanic[titanic.Survived == 0]
didntsurvive.describe()
# Out:
#        Survived      Pclass         Age       SibSp       Parch        Fare
# count     549.0  549.000000  549.000000  549.000000  549.000000  549.000000
# mean        0.0    2.531876   30.415100    0.553734    0.329690   22.117887
# std         0.0    0.735805   12.457370    1.288399    0.823166   31.388207
# min         0.0    1.000000    1.000000    0.000000    0.000000    0.000000
# 25%         0.0    2.000000   23.000000    0.000000    0.000000    7.854200
# 50%         0.0    3.000000   29.699118    0.000000    0.000000   10.500000
# 75%         0.0    3.000000   35.000000    1.000000    0.000000   26.000000
# max         0.0    3.000000   74.000000    8.000000    6.000000  263.000000

# %%
survivedS = titanic[titanic.Embarked == 'Q'][titanic.Survived == 1].shape[0]
survivedS
# Out:
# /Users/asingla/anaconda2/envs/py3k/lib/python3.6/site-packages/ipykernel/__main__.py:1: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   if __name__ == '__main__':
# 30

# %%
titanic.dropna(inplace = True)
titanic.shape
# Out:
# (889, 8)

# %%
def getNumber(str):
    if (str == 'male'):
        return 1
    else :
        return 2

titanic['gender'] = titanic['Sex'].apply(getNumber)
titanic.head()
del titanic['Sex']
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /Users/asingla/anaconda2/envs/py3k/lib/python3.6/site-packages/pandas/indexes/base.py in get_loc(self, key, method, tolerance)
#    2133             try:
# -> 2134                 return self._engine.get_loc(key)
#    2135             except KeyError:
#
# pandas/index.pyx in pandas.index.IndexEngine.get_loc (pandas/index.c:4433)()
#
# pandas/index.pyx in pandas.index.IndexEngine.get_loc (pandas/index.c:4279)()
#
# pandas/src/hashtable_class_helper.pxi in pandas.hashtable.PyObjectHashTable.get_item (pandas/hashtable.c:13742)()
#
# pandas/src/hashtable_class_helper.pxi in pandas.hashtable.PyObjectHashTable.get_item (pandas/hashtable.c:13696)()
#
# KeyError: 'Sex'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# ...

# %%
titanic.head()
# Out:
#    Survived  Pclass   Age  SibSp  Parch     Fare Embarked  gender
# 0         0       3  22.0      1      0   7.2500        S       1
# 1         1       1  38.0      1      0  71.2833        C       2
# 2         1       3  26.0      0      0   7.9250        S       2
# 3         1       1  35.0      1      0  53.1000        S       2
# 4         0       3  35.0      0      0   8.0500        S       1

# %%
males = (titanic['gender'] == 1).sum()
females = (titanic['gender'] == 2).sum()

p = [males, females]
plt.pie(p,
       labels = ['Male', 'Female'],
       colors = ['blue', 'red'],
       explode = (0.15, 0),
       startangle = 0)
plt.axis('equal')
plt.show()

# %%
titanic = pd.read_csv('titanic_train.csv')
titanic = titanic[titanic.Survived == 1][pd.isnull(titanic['Age'])]

titanic
# Out:
# /Users/asingla/anaconda2/envs/py3k/lib/python3.6/site-packages/ipykernel/__main__.py:2: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   from ipykernel import kernelapp as app
#      PassengerId  Survived  Pclass  \
# 17            18         1       2
# 19            20         1       3
# 28            29         1       3
# 31            32         1       1
# 32            33         1       3
# 36            37         1       3
# 47            48         1       3
# 55            56         1       1
# 65            66         1       3
# 82            83         1       3
# 107          108         1       3
# 109          110         1       3
# 128          129         1       3
# 166          167         1       1
# 186          187         1       3
# 198          199         1       3
# 241          242         1       3
# 256          257         1       1
# 274          275         1       3
# 298          299         1       1
# ...

# %%
titanic = pd.read_csv('titanic_train.csv')
titanic = titanic[titanic.Survived == 1][pd.isnull(titanic['Age'])]

titanic
# Out:
# /Users/asingla/anaconda2/envs/py3k/lib/python3.6/site-packages/ipykernel/__main__.py:2: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   from ipykernel import kernelapp as app
#      PassengerId  Survived  Pclass  \
# 17            18         1       2
# 19            20         1       3
# 28            29         1       3
# 31            32         1       1
# 32            33         1       3
# 36            37         1       3
# 47            48         1       3
# 55            56         1       1
# 65            66         1       3
# 82            83         1       3
# 107          108         1       3
# 109          110         1       3
# 128          129         1       3
# 166          167         1       1
# 186          187         1       3
# 198          199         1       3
# 241          242         1       3
# 256          257         1       1
# 274          275         1       3
# 298          299         1       1
# ...
