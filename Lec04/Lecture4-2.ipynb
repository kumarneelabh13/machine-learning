# %%
import pandas as pd
from sklearn import datasets
from IPython.core.interactiveshell import InteractiveShell
InteractiveShell.ast_node_interactivity = "all"

# %%
iris=datasets.load_iris()
df=pd.DataFrame(iris.data)
df
# Out:
#        0    1    2    3
# 0    5.1  3.5  1.4  0.2
# 1    4.9  3.0  1.4  0.2
# 2    4.7  3.2  1.3  0.2
# 3    4.6  3.1  1.5  0.2
# 4    5.0  3.6  1.4  0.2
# 5    5.4  3.9  1.7  0.4
# 6    4.6  3.4  1.4  0.3
# 7    5.0  3.4  1.5  0.2
# 8    4.4  2.9  1.4  0.2
# 9    4.9  3.1  1.5  0.1
# 10   5.4  3.7  1.5  0.2
# 11   4.8  3.4  1.6  0.2
# 12   4.8  3.0  1.4  0.1
# 13   4.3  3.0  1.1  0.1
# 14   5.8  4.0  1.2  0.2
# 15   5.7  4.4  1.5  0.4
# 16   5.4  3.9  1.3  0.4
# 17   5.1  3.5  1.4  0.3
# 18   5.7  3.8  1.7  0.3
# 19   5.1  3.8  1.5  0.3
# 20   5.4  3.4  1.7  0.2
# 21   5.1  3.7  1.5  0.4
# 22   4.6  3.6  1.0  0.2
# 23   5.1  3.3  1.7  0.5
# 24   4.8  3.4  1.9  0.2
# 25   5.0  3.0  1.6  0.2
# 26   5.0  3.4  1.6  0.4
# 27   5.2  3.5  1.5  0.2
# 28   5.2  3.4  1.4  0.2
# 29   4.7  3.2  1.6  0.2
# ..   ...  ...  ...  ...
# 120  6.9  3.2  5.7  2.3
# 121  5.6  2.8  4.9  2.0
# 122  7.7  2.8  6.7  2.0
# 123  6.3  2.7  4.9  1.8
# 124  6.7  3.3  5.7  2.1
# 125  7.2  3.2  6.0  1.8
# ...

# %%
df.columns=iris.feature_names
df.head()
# Out:
#    sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)
# 0                5.1               3.5                1.4               0.2
# 1                4.9               3.0                1.4               0.2
# 2                4.7               3.2                1.3               0.2
# 3                4.6               3.1                1.5               0.2
# 4                5.0               3.6                1.4               0.2

# %%
from sklearn.linear_model import LinearRegression
from sklearn import cross_validation
clf=LinearRegression()
x_train, x_test, y_train, y_test=cross_validation.train_test_split(df, iris.target, test_size=0.2)

# %%
clf.fit(x_train, y_train)
y_pred=clf.predict(x_test)
y_pred
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=1, normalize=False)
# array([ 0.03133149,  1.74137444,  1.87206627,  2.20658286,  0.24586412,
#         2.03737057,  1.37673693, -0.11576945,  1.3934391 ,  0.03875774,
#         1.47736426,  0.00315867,  1.99232534,  1.39422059,  1.43111191,
#         1.60837504,  1.20069963,  2.02157246, -0.08995804, -0.10685558,
#         1.50644215,  2.01521793,  1.53969239,  1.52221154,  2.0240754 ,
#         2.17854618, -0.05307929,  1.42485507, -0.1186757 ,  2.13112698])

# %%
y_test
# Out:
# array([0, 2, 2, 2, 0, 2, 1, 0, 1, 0, 2, 0, 2, 1, 2, 2, 1, 2, 0, 0, 1, 2, 1,
#        2, 2, 2, 0, 1, 0, 2])

# %%
score=clf.score(x_test, y_test)
score
# Out:
# 0.88768742091492725

# %%
from sklearn.metrics import confusion_matrix
confusion_matrix(y_pred.astype(int),y_test)
# Out:
# array([[9, 0, 0],
#        [0, 7, 7],
#        [0, 0, 7]])

# %%
from sklearn.metrics import classification_report

print(classification_report(y_test, y_pred.astype(int))
)
# Out:
#              precision    recall  f1-score   support
#
#           0       1.00      1.00      1.00         9
#           1       0.50      1.00      0.67         7
#           2       1.00      0.50      0.67        14
#
# avg / total       0.88      0.77      0.77        30

# %%
from sklearn.model_selection import cross_val_score
from sklearn.svm  import SVC

# %%
cllf=SVC()

# %%
scores= cross_val_score(cllf, iris.data, iris.target, cv=5)
scores.mean()
# Out:
# 0.98000000000000009
