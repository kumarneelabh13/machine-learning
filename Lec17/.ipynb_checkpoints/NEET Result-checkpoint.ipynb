# %%
import numpy as np
import pandas as pd

# %%
df = pd.read_csv('NEET Result.csv')

# %%
del df['Unnamed: 6']

# %%
df = df.drop_duplicates()
df.columns
# Out:
# Index(['Sl.\nNo.', 'Application\nNumber', 'NEET UG\n2017 Roll\nNumber',
#        'Candidate', 'Candidate's Father', 'Candidate's Mother',
#        'NEET All\nIndia Rank', 'Region', 'Category', 'PWD', 'DEFENCE', 'ARMY',
#        'Eligibility\n*'],
#       dtype='object')

# %%
df = df.drop_duplicates(subset='NEET UG\n2017 Roll\nNumber')
df = df.dropna()
df = df.drop(df.index[[29]])
df
# Out:
#       Sl.\nNo. Application\nNumber NEET UG\n2017 Roll\nNumber  \
# 0            1              205456                  907810487
# 1            2              154241                  902903039
# 2            3              204756                  907503311
# 3            4              320562                  907504378
# 4            5              214830                  908102502
# 5            6              193638                  907705104
# 6            7              125692                  901806926
# 7            8              231058                  908102861
# 8            9              185072                  902906338
# 9           10              159246                  907504159
# 10          11              133934                  910103923
# 11          12              125839                  901907597
# 12          13              193964                  907704462
# 13          14              179283                  901903508
# ...

# %%
df_delhi = df[df['Region'] == 'Delhi/All India']
df_delhi = df_delhi.reset_index()
df_delhi_general[df_delhi_general['Candidate'] == 'DIVYA DAS']
# Out:
#      level_0  index Sl.\nNo. Application\nNumber NEET UG\n2017 Roll\nNumber  \
# 284      333   1034      811              116087                  901709521
#
#      Candidate Candidate's Father Candidate's Mother NEET All\nIndia Rank  \
# 284  DIVYA DAS            D K DAS        SUCHITA DAS                 4021
#
#               Region Category PWD DEFENCE ARMY Eligibility\n*
# 284  Delhi/All India  General  No      No   No            Yes

# %%
del df_delhi_general['level_0']

# %%
del df_delhi_general['index']

# %%
DF = df_delhi_general

# %%
inelg = df[df['Eligibility\n*'] == 'No']
inelg
# Out:
#       Sl.\nNo. Application\nNumber NEET UG\n2017 Roll\nNumber       Candidate  \
# 23928    18729              225913                  901606061     CHARUL KAIN
# 23929    18730              154970                  901500735  JYOTI KUSHWAHA
# 23930    18731              196342                  901506223      RAFAT BANO
# 23931    18732              226515                  901604405     SANDHYA SAI
#
#       Candidate's Father Candidate's Mother NEET All\nIndia Rank  \
# 23928           K L KAIN      DARSHANA KAIN                   --
# 23929          RAM KUMAR           SANGEETA                   --
# 23930     SHAKEEL AHAMAD      SHAHNAZ BEGAM                   --
# 23931        VIJAY KUMAR          ASHA RANI                   --
#
#                 Region     Category PWD DEFENCE ARMY Eligibility\n*
# 23928  Delhi/All India  General/OBC  No      No   No             No
# 23929  Delhi/All India  General/OBC  No      No   No             No
# ...
