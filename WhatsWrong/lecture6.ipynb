# %%
import quandl
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import seaborn as sns
from sklearn.model_selection import cross_val_score
from sklearn import preprocessing
from sklearn import model_selection

# %%
df = quandl.get('WIKI/GOOGL')

# %%
df
# Out:
#                 Open       High       Low     Close      Volume  Ex-Dividend  \
# Date
# 2004-08-19   100.010   104.0600   95.9600   100.335  44659000.0          0.0
# 2004-08-20   101.010   109.0800  100.5000   108.310  22834300.0          0.0
# 2004-08-23   110.760   113.4800  109.0500   109.400  18256100.0          0.0
# 2004-08-24   111.240   111.6000  103.5700   104.870  15247300.0          0.0
# 2004-08-25   104.760   108.0000  103.8800   106.000   9188600.0          0.0
# 2004-08-26   104.950   107.9500  104.6600   107.910   7094800.0          0.0
# 2004-08-27   108.100   108.6200  105.6900   106.150   6211700.0          0.0
# 2004-08-30   105.280   105.4900  102.0100   102.010   5196700.0          0.0
# 2004-08-31   102.320   103.7100  102.1600   102.370   4917800.0          0.0
# 2004-09-01   102.700   102.9700   99.6700   100.250   9138200.0          0.0
# 2004-09-02    99.090   102.3700   98.9400   101.510  15118600.0          0.0
# ...

# %%
df.describe()
# Out:
#               Open         High          Low        Close        Volume  \
# count  3230.000000  3230.000000  3230.000000  3230.000000  3.230000e+03
# mean    570.808186   576.100830   564.956712   570.566407  8.184781e+06
# std     206.271015   206.836971   205.366282   206.180941  8.349518e+06
# min      99.090000   101.740000    95.960000   100.010000  5.211410e+05
# 25%     451.540000   457.237500   446.130000   450.465000  2.921750e+06
# 50%     553.805000   558.805000   547.600000   553.670000  5.402300e+06
# 75%     690.605000   697.247500   682.396775   691.417500  1.082905e+07
# max    1226.800000  1228.880000  1218.600000  1220.170000  8.215110e+07
#
#        Ex-Dividend  Split Ratio    Adj. Open    Adj. High     Adj. Low  \
# count  3230.000000       3230.0  3230.000000  3230.000000  3230.000000
# mean      0.175843          1.0   372.172566   375.474696   368.480699
# std       9.993679          0.0   214.286981   215.399513   212.864128
# ...

# %%
df.shape
df.tail()
#create new y
#drop split ratio
#add percentage change in opening and close
#remove high
#add percentage change between high and low
#use adj high and adj low
# Out:
#               Open      High       Low   Close     Volume  Ex-Dividend  \
# Date
# 2017-06-12  958.72  968.0000  936.7950  961.81  4167184.0          0.0
# 2017-06-13  972.04  977.9100  962.0100  970.50  1992456.0          0.0
# 2017-06-14  975.50  979.7000  959.5103  967.93  1489046.0          0.0
# 2017-06-15  948.02  960.6775  940.3700  960.18  2349212.0          0.0
# 2017-06-16  957.91  959.9500  948.7000  958.62  2484914.0          0.0
#
#             Split Ratio  Adj. Open  Adj. High  Adj. Low  Adj. Close  \
# Date
# 2017-06-12          1.0     958.72   968.0000  936.7950      961.81
# 2017-06-13          1.0     972.04   977.9100  962.0100      970.50
# 2017-06-14          1.0     975.50   979.7000  959.5103      967.93
# 2017-06-15          1.0     948.02   960.6775  940.3700      960.18
# 2017-06-16          1.0     957.91   959.9500  948.7000      958.62
#
#             Adj. Volume
# Date
# 2017-06-12    4167184.0
# 2017-06-13    1992456.0
# 2017-06-14    1489046.0
# ...

# %%
del df['Split Ratio']

# %%
df
# Out:
#                 Open       High       Low     Close      Volume  Ex-Dividend  \
# Date
# 2004-08-19   100.010   104.0600   95.9600   100.335  44659000.0          0.0
# 2004-08-20   101.010   109.0800  100.5000   108.310  22834300.0          0.0
# 2004-08-23   110.760   113.4800  109.0500   109.400  18256100.0          0.0
# 2004-08-24   111.240   111.6000  103.5700   104.870  15247300.0          0.0
# 2004-08-25   104.760   108.0000  103.8800   106.000   9188600.0          0.0
# 2004-08-26   104.950   107.9500  104.6600   107.910   7094800.0          0.0
# 2004-08-27   108.100   108.6200  105.6900   106.150   6211700.0          0.0
# 2004-08-30   105.280   105.4900  102.0100   102.010   5196700.0          0.0
# 2004-08-31   102.320   103.7100  102.1600   102.370   4917800.0          0.0
# 2004-09-01   102.700   102.9700   99.6700   100.250   9138200.0          0.0
# 2004-09-02    99.090   102.3700   98.9400   101.510  15118600.0          0.0
# ...

# %%
del df['Open']
del df['High']
del df['Low']
del df['Close']
del df['Volume']

# %%
del df['Ex-Dividend']
df
# Out:
#               Adj. Open    Adj. High    Adj. Low   Adj. Close  Adj. Volume
# Date
# 2004-08-19    50.159839    52.191109   48.128568    50.322842   44659000.0
# 2004-08-20    50.661387    54.708881   50.405597    54.322689   22834300.0
# 2004-08-23    55.551482    56.915693   54.693835    54.869377   18256100.0
# 2004-08-24    55.792225    55.972783   51.945350    52.597363   15247300.0
# 2004-08-25    52.542193    54.167209   52.100830    53.164113    9188600.0
# 2004-08-26    52.637487    54.142132   52.492038    54.122070    7094800.0
# 2004-08-27    54.217364    54.478169   53.008633    53.239345    6211700.0
# 2004-08-30    52.802998    52.908323   51.162935    51.162935    5196700.0
# 2004-08-31    51.318415    52.015567   51.238167    51.343492    4917800.0
# 2004-09-01    51.509003    51.644421   49.989312    50.280210    9138200.0
# 2004-09-02    49.698414    51.343492   49.623182    50.912161   15118600.0
# ...

# %%
df.reset_index(drop = True, inplace = True)

# %%
df['Target']= df[0:len(df)-5]['Adj. Open']

df
# Out:
#         Adj. Open    Adj. High    Adj. Low   Adj. Close  Adj. Volume  \
# 0       50.159839    52.191109   48.128568    50.322842   44659000.0
# 1       50.661387    54.708881   50.405597    54.322689   22834300.0
# 2       55.551482    56.915693   54.693835    54.869377   18256100.0
# 3       55.792225    55.972783   51.945350    52.597363   15247300.0
# 4       52.542193    54.167209   52.100830    53.164113    9188600.0
# 5       52.637487    54.142132   52.492038    54.122070    7094800.0
# 6       54.217364    54.478169   53.008633    53.239345    6211700.0
# 7       52.802998    52.908323   51.162935    51.162935    5196700.0
# 8       51.318415    52.015567   51.238167    51.343492    4917800.0
# 9       51.509003    51.644421   49.989312    50.280210    9138200.0
# 10      49.698414    51.343492   49.623182    50.912161   15118600.0
# 11      50.631294    51.027517   49.813770    50.159839    5152400.0
# 12      50.661387    51.157920   49.959219    50.947269    5847500.0
# ...

# %%
df.dropna(axis = 0, inplace = True)

df.shape
df.tail()
# Out:
#       Adj. Open  Adj. High  Adj. Low  Adj. Close  Adj. Volume   Target
# 3220     997.89    1007.40    995.45     1003.88    1353264.0   997.89
# 3221    1003.31    1008.61    994.80      996.68    1517356.0  1003.31
# 3222     998.82    1003.91    995.81     1001.59    1348198.0   998.82
# 3223    1004.23    1005.60    996.62     1004.28    1657881.0  1004.23
# 3224    1005.49    1005.50    953.37      970.12    3613964.0  1005.49

# %%
from sklearn.linear_model import LinearRegression

# %%
from sklearn import cross_validation
clf = LinearRegression()
array = df.values
X = array[:,0:6]
Y = ['Target']
# Out:
# C:\Users\SOMYAA\Anaconda3\lib\site-packages\sklearn\cross_validation.py:44: DeprecationWarning: This module was deprecated in version 0.18 in favor of the model_selection module into which all the refactored classes and functions are moved. Also note that the interface of the new CV iterators are different from that of this module. This module will be removed in 0.20.
#   "This module will be removed in 0.20.", DeprecationWarning)

# %%
s = 7

# %%
X_Train, X_Test, Y_Train, Y_Test = cross_validation.train_test_split(X, df['Target'], test_size = 0.25)

# %%
clf.fit(X_Train,Y_Train)
Predict = clf.predict(X_Test)
score = clf.score(X_Test,Y_Test)
score
# Out:
# 1.0

# %%
#apply feature scaling
X_Scaled = preprocessing.scale(X)

#change = adj open- target/adj open*100
